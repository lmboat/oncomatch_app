# %%
import os, sys
import numpy as np
import pandas as pd

# %%
from rdkit import Chem
from rdkit.Chem import *
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem.rdMolDescriptors import *
from rdkit import DataStructs
from rdkit.Chem import AllChem

# %% [markdown]
# #

# %% [markdown]
# # Read DrugCentral

# %%
drugid_df = pd.read_csv('../data/DeepCoverageMOA/drug.structure.id.csv')
drugid_df.head()
# Out:
#           DRUG_NAME  STRUCT_ID
# 0   levobupivacaine          4
# 1   (S)-nicardipine          5
# 2  (S)-nitrendipine          6
# 3     levdobutamine         13
# 4       aminopterin         21

# %% [markdown]
# #

# %% [markdown]
# # Read SMILES IDs

# %%
smiles_df = pd.read_csv('../data/DrugCentral/raw_data/structures.smiles.tsv', sep = '\t')
smiles_df.head()
# Out:
#                                               SMILES  \
# 0  CNC(=O)C1=C(C=C(C=C1)C2=NN3C(=CN=C3N=C2)CC4=CC...
# 1  CC(C)(COC1=CN2C(=C(C=N2)C#N)C(=C1)C3=CN=C(C=C3...
# 2  CCN1C2=CC(=NC=C2C=C(C1=O)C3=CC(=C(C=C3Br)F)NC(...
# 3  C[C@]12CC[C@H]3[C@H]([C@@H]1C[C@H]([C@@H]2O)[1...
# 4      C1=CC2=C(C=C1C3=CN=C(C=C3)[18F])NC4=C2C=NC=C4
#
#                                                InChI  \
# 0  InChI=1S/C23H17FN6O/c1-25-22(31)18-6-5-16(11-1...
# 1  InChI=1S/C29H31N7O3/c1-29(2,37)18-39-24-9-25(2...
# 2  InChI=1S/C24H21BrFN5O2/c1-3-31-21-12-22(27-2)2...
# 3  InChI=1S/C18H23FO2/c1-18-7-6-13-12-5-3-11(20)8...
# 4  InChI=1S/C16H10FN3/c17-16-4-2-11(8-19-16)10-1-...
#
#                       InChIKey    ID                   INN        CAS_RN
# 0  LIOLIMKSCNQPLV-UHFFFAOYSA-N  5392            capmatinib  1029712-80-8
# 1  XIIOFHFUYBLOLW-UHFFFAOYSA-N  5393         selpercatinib  2152628-33-4
# 2  CEFJVGZHQAGLHS-UHFFFAOYSA-N  5394            ripretinib  1442472-39-0
# 3  KDLLNMRYZGUVMA-ZYMZXAKXSA-N  5395  fluoroestradiol F 18    94153-53-4
# 4  GETAAWDSFUCLBS-SJPDSGJFSA-N  5396     flortaucipir F 18  1522051-90-6

# %%
subset_smiles_df = smiles_df[['SMILES', 'ID', 'INN']].drop_duplicates()

# %%
def standardize_smiles(df, smiles_col):
    smiles_list = df['SMILES']
    mol_list = [Chem.MolFromSmiles(smiles) for smiles in smiles_list]

    df['Molecule'] = mol_list
    
    new_smiles_list = [Chem.MolToSmiles(mol) for mol in mol_list]
    df['SMILES_String'] = new_smiles_list

    return df

# %%
subset_smiles_df = standardize_smiles(subset_smiles_df, 'SMILES')
# Out:
# [14:01:57] WARNING: not removing hydrogen atom without neighbors

# %%
subset_smiles_df
# Out:
#                                                  SMILES    ID  \
# 0     CNC(=O)C1=C(C=C(C=C1)C2=NN3C(=CN=C3N=C2)CC4=CC...  5392
# 1     CC(C)(COC1=CN2C(=C(C=N2)C#N)C(=C1)C3=CN=C(C=C3...  5393
# 2     CCN1C2=CC(=NC=C2C=C(C1=O)C3=CC(=C(C=C3Br)F)NC(...  5394
# 3     C[C@]12CC[C@H]3[C@H]([C@@H]1C[C@H]([C@@H]2O)[1...  5395
# 4         C1=CC2=C(C=C1C3=CN=C(C=C3)[18F])NC4=C2C=NC=C4  5396
# ...                                                 ...   ...
# 4094  COC(=O)[C@@H]([C@H]1CCCCN1C(=O)OC[N+]2=CC=CC(=...  5448
# 4095  C[C@]12CC[C@H]3[C@H]([C@@H]1[C@H]([C@H]([C@@H]...  5450
# 4096      OC(=O)CC[C@H](NC(=O)N[C@@H](CCCCNC(=O)C1=C...  5458
# 4097  CCN1CCN(CC1)C2=CC=C(C=C2)NC3=CC(=NC=N3)N(C)C(=...  5459
# 4098  C1CC1CN2CCC34CC(=O)CCC3(C2CC5=C4C(=C(C=C5)C(=O...  5460
#
#                         INN                                       Molecule  \
# 0                capmatinib  <rdkit.Chem.rdchem.Mol object at 0x144a88eb0>
# 1             selpercatinib  <rdkit.Chem.rdchem.Mol object at 0x144a893f0>
# 2                ripretinib  <rdkit.Chem.rdchem.Mol object at 0x144a89380>
# 3      fluoroestradiol F 18  <rdkit.Chem.rdchem.Mol object at 0x144a89310>
# 4         flortaucipir F 18  <rdkit.Chem.rdchem.Mol object at 0x144a892a0>
# ...                     ...                                            ...
# 4094  serdexmethylphenidate  <rdkit.Chem.rdchem.Mol object at 0x144f25000>
# 4095               estetrol  <rdkit.Chem.rdchem.Mol object at 0x144f25070>
# 4096     piflufolastat F-18  <rdkit.Chem.rdchem.Mol object at 0x144f250e0>
# 4097           infigratinib  <rdkit.Chem.rdchem.Mol object at 0x144f25150>
# 4098            samidorphan  <rdkit.Chem.rdchem.Mol object at 0x144f251c0>
#
#                                           SMILES_String
# 0     CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F
# 1     COc1ccc(CN2C3CC2CN(c2ccc(-c4cc(OCC(C)(C)O)cn5n...
# 2     CCn1c(=O)c(-c2cc(NC(=O)Nc3ccccc3)c(F)cc2Br)cc2...
# 3     C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1C[C@...
# 4              [18F]c1ccc(-c2ccc3c(c2)[nH]c2ccncc23)cn1
# ...                                                 ...
# 4094  COC(=O)[C@H](c1ccccc1)[C@H]1CCCCN1C(=O)OC[n+]1...
# 4095  C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1[C@@...
# 4096  O=C(O)CC[C@H](NC(=O)N[C@@H](CCCCNC(=O)c1ccc([1...
# 4097  CCN1CCN(c2ccc(Nc3cc(N(C)C(=O)Nc4c(Cl)c(OC)cc(O...
# 4098  NC(=O)c1ccc2c(c1O)C13CCN(CC4CC4)C(C2)C1(O)CCC(...
#
# [4099 rows x 5 columns]

# %%
structure_drugid_df = pd.merge(subset_smiles_df, drugid_df, left_on = 'INN', right_on = 'DRUG_NAME', how = 'left')

# %%
structure_drugid_df
# Out:
#                                                  SMILES    ID  \
# 0     CNC(=O)C1=C(C=C(C=C1)C2=NN3C(=CN=C3N=C2)CC4=CC...  5392
# 1     CC(C)(COC1=CN2C(=C(C=N2)C#N)C(=C1)C3=CN=C(C=C3...  5393
# 2     CCN1C2=CC(=NC=C2C=C(C1=O)C3=CC(=C(C=C3Br)F)NC(...  5394
# 3     C[C@]12CC[C@H]3[C@H]([C@@H]1C[C@H]([C@@H]2O)[1...  5395
# 4         C1=CC2=C(C=C1C3=CN=C(C=C3)[18F])NC4=C2C=NC=C4  5396
# ...                                                 ...   ...
# 4094  COC(=O)[C@@H]([C@H]1CCCCN1C(=O)OC[N+]2=CC=CC(=...  5448
# 4095  C[C@]12CC[C@H]3[C@H]([C@@H]1[C@H]([C@H]([C@@H]...  5450
# 4096      OC(=O)CC[C@H](NC(=O)N[C@@H](CCCCNC(=O)C1=C...  5458
# 4097  CCN1CCN(CC1)C2=CC=C(C=C2)NC3=CC(=NC=N3)N(C)C(=...  5459
# 4098  C1CC1CN2CCC34CC(=O)CCC3(C2CC5=C4C(=C(C=C5)C(=O...  5460
#
#                         INN                                       Molecule  \
# 0                capmatinib  <rdkit.Chem.rdchem.Mol object at 0x144a88eb0>
# 1             selpercatinib  <rdkit.Chem.rdchem.Mol object at 0x144a893f0>
# 2                ripretinib  <rdkit.Chem.rdchem.Mol object at 0x144a89380>
# 3      fluoroestradiol F 18  <rdkit.Chem.rdchem.Mol object at 0x144a89310>
# 4         flortaucipir F 18  <rdkit.Chem.rdchem.Mol object at 0x144a892a0>
# ...                     ...                                            ...
# 4094  serdexmethylphenidate  <rdkit.Chem.rdchem.Mol object at 0x144f25000>
# 4095               estetrol  <rdkit.Chem.rdchem.Mol object at 0x144f25070>
# 4096     piflufolastat F-18  <rdkit.Chem.rdchem.Mol object at 0x144f250e0>
# 4097           infigratinib  <rdkit.Chem.rdchem.Mol object at 0x144f25150>
# 4098            samidorphan  <rdkit.Chem.rdchem.Mol object at 0x144f251c0>
#
#                                           SMILES_String             DRUG_NAME  \
# 0     CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F            capmatinib
# 1     COc1ccc(CN2C3CC2CN(c2ccc(-c4cc(OCC(C)(C)O)cn5n...         selpercatinib
# 2     CCn1c(=O)c(-c2cc(NC(=O)Nc3ccccc3)c(F)cc2Br)cc2...            ripretinib
# 3     C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1C[C@...  fluoroestradiol F 18
# 4              [18F]c1ccc(-c2ccc3c(c2)[nH]c2ccncc23)cn1     flortaucipir F 18
# ...                                                 ...                   ...
# 4094  COC(=O)[C@H](c1ccccc1)[C@H]1CCCCN1C(=O)OC[n+]1...                   NaN
# 4095  C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1[C@@...              estetrol
# 4096  O=C(O)CC[C@H](NC(=O)N[C@@H](CCCCNC(=O)c1ccc([1...    piflufolastat F-18
# 4097  CCN1CCN(c2ccc(Nc3cc(N(C)C(=O)Nc4c(Cl)c(OC)cc(O...          infigratinib
# 4098  NC(=O)c1ccc2c(c1O)C13CCN(CC4CC4)C(C2)C1(O)CCC(...           samidorphan
#
#       STRUCT_ID
# 0        5392.0
# 1        5393.0
# 2        5394.0
# 3        5395.0
# 4        5396.0
# ...         ...
# 4094        NaN
# 4095     5450.0
# 4096     5458.0
# 4097     5459.0
# 4098     5460.0
#
# [4099 rows x 7 columns]

# %% [markdown]
# #

# %% [markdown]
# # Read DeepCoverageMOA IDs

# %%
dcmoa_id_df = pd.read_excel('../data/DeepCoverageMOA/raw_data/41587_2022_1539_MOESM4_ESM.xlsx')

# %%
dcmoa_id_df.head()
# Out:
#   Compound Name Primary Target Secondary Target  \
# 0     SR 142948          NTSR1            NTSR2
# 1     UK 356618           MMP3       MMP13;MMP9
# 2        JW 480          NCEH1              NaN
# 3        ML-265            PKM              NaN
# 4   PF-04418948         PTGER2              NaN
#
#                                               SMILES      MW       Formula  \
# 0  COc1cccc(c1c1cc(nn1c1ccc(cc1C(C)C)C(=O)N(CCCN(...  685.38    C39H51N5O6
# 1  ONC(=O)C[C@H](C(=O)N[C@@H](C(C)(C)C)C(=O)N[C@@...  557.32    C34H43N3O4
# 2             O=C(Oc1ccccc1C(C)C)NCCc1ccc2c(c1)cccc2  333.17     C22H23NO2
# 3      Nc1cccc(c1)Cn1ncc2c(c1=O)n(C)c1c2sc(c1)S(=O)C  372.07  C17H16N4O2S2
# 4  COc1ccc2c(c1)ccc(c2)OCC1(CN(C1)C(=O)c1ccc(cc1)...  409.13    C23H20FNO5
#
#   Screening Concentration
# 0                    10uM
# 1                    10uM
# 2                    10uM
# 3                    10uM
# 4                    10uM

# %%
dcmoa_id_df = standardize_smiles(dcmoa_id_df, 'SMILES')

# %%
dcmoa_id_df
# Out:
#      Compound Name Primary Target  \
# 0        SR 142948          NTSR1
# 1        UK 356618           MMP3
# 2           JW 480          NCEH1
# 3           ML-265            PKM
# 4      PF-04418948         PTGER2
# ..             ...            ...
# 870      Celastrol           IL1B
# 871       UNC 0631          EHMT2
# 872  Pyrimethamine           DHFR
# 873     Darapladib         PLA2G7
# 874      Nilotinib           ABL1
#
#                                       Secondary Target  \
# 0                                                NTSR2
# 1                                           MMP13;MMP9
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 870                                                NaN
# 871                                                NaN
# 872                                              GSTP1
# 873                                                NaN
# 874  DDR2;BCR;KIT;PDGFRB;DDR1;ABL2;PDGFRA;MAP3K20;M...
#
#                                                 SMILES      MW        Formula  \
# 0    COc1cccc(c1c1cc(nn1c1ccc(cc1C(C)C)C(=O)N(CCCN(...  685.38     C39H51N5O6
# 1    ONC(=O)C[C@H](C(=O)N[C@@H](C(C)(C)C)C(=O)N[C@@...  557.32     C34H43N3O4
# 2               O=C(Oc1ccccc1C(C)C)NCCc1ccc2c(c1)cccc2  333.17      C22H23NO2
# 3        Nc1cccc(c1)Cn1ncc2c(c1=O)n(C)c1c2sc(c1)S(=O)C  372.07   C17H16N4O2S2
# 4    COc1ccc2c(c1)ccc(c2)OCC1(CN(C1)C(=O)c1ccc(cc1)...  409.13     C23H20FNO5
# ..                                                 ...     ...            ...
# 870  O=C1C=C2C(=CC=C3[C@@]2(C)CC[C@@]2([C@]3(C)CC[C...  450.28       C29H38O4
# 871  COC1=CC2=C(NC3CCN(CC4CCCCC4)CC3)N=C(N5CCN(C(C)...  635.49     C37H61N7O2
# 872               CCC1=C(C(=NC(=N1)N)N)C2=CC=C(Cl)C=C2  248.08     C12H13ClN4
# 873  CCN(CCN(C(=O)Cn1c(SCc2ccc(cc2)F)nc(=O)c2c1CCC2...  666.26  C36H38F4N4O2S
# 874  O=C(NC1=CC(C(F)(F)F)=CC(N2C=NC(C)=C2)=C1)C3=CC...  529.18    C28H22F3N7O
#
#     Screening Concentration                                       Molecule  \
# 0                      10uM  <rdkit.Chem.rdchem.Mol object at 0x1603f4b30>
# 1                      10uM  <rdkit.Chem.rdchem.Mol object at 0x1603f4e40>
# 2                      10uM  <rdkit.Chem.rdchem.Mol object at 0x1603f4dd0>
# 3                      10uM  <rdkit.Chem.rdchem.Mol object at 0x1603f4c80>
# 4                      10uM  <rdkit.Chem.rdchem.Mol object at 0x1603f4c10>
# ..                      ...                                            ...
# 870                     1uM  <rdkit.Chem.rdchem.Mol object at 0x160400970>
# 871                     1uM  <rdkit.Chem.rdchem.Mol object at 0x1604009e0>
# 872                     1uM  <rdkit.Chem.rdchem.Mol object at 0x160400a50>
# 873                     1uM  <rdkit.Chem.rdchem.Mol object at 0x160400ac0>
# 874                     1uM  <rdkit.Chem.rdchem.Mol object at 0x160400b30>
#
#                                          SMILES_String
# 0    COc1cccc(OC)c1-c1cc(C(=O)NC2(C(=O)O)C3CC4CC(C3...
# 1    Cc1cc(CCC[C@H](CC(=O)NO)C(=O)N[C@H](C(=O)N[C@H...
# 2                 CC(C)c1ccccc1OC(=O)NCCc1ccc2ccccc2c1
# 3        Cn1c2cc(S(C)=O)sc2c2cnn(Cc3cccc(N)c3)c(=O)c21
# 4    COc1ccc2cc(OCC3(C(=O)O)CN(C(=O)c4ccc(F)cc4)C3)...
# ..                                                 ...
# 870  CC1=C(O)C(=O)C=C2C1=CC=C1[C@@]2(C)CC[C@@]2(C)[...
# 871  COc1cc2c(NC3CCN(CC4CCCCC4)CC3)nc(N3CCCN(C(C)C)...
# 872                      CCc1nc(N)nc(N)c1-c1ccc(Cl)cc1
# 873  CCN(CC)CCN(Cc1ccc(-c2ccc(C(F)(F)F)cc2)cc1)C(=O...
# 874  Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)...
#
# [875 rows x 9 columns]

# %%
subset_dcmoa_id_df = dcmoa_id_df[['SMILES_String', 'Compound Name']]

# %%
subset_dcmoa_id_df
# Out:
#                                          SMILES_String  Compound Name
# 0    COc1cccc(OC)c1-c1cc(C(=O)NC2(C(=O)O)C3CC4CC(C3...      SR 142948
# 1    Cc1cc(CCC[C@H](CC(=O)NO)C(=O)N[C@H](C(=O)N[C@H...      UK 356618
# 2                 CC(C)c1ccccc1OC(=O)NCCc1ccc2ccccc2c1         JW 480
# 3        Cn1c2cc(S(C)=O)sc2c2cnn(Cc3cccc(N)c3)c(=O)c21         ML-265
# 4    COc1ccc2cc(OCC3(C(=O)O)CN(C(=O)c4ccc(F)cc4)C3)...    PF-04418948
# ..                                                 ...            ...
# 870  CC1=C(O)C(=O)C=C2C1=CC=C1[C@@]2(C)CC[C@@]2(C)[...      Celastrol
# 871  COc1cc2c(NC3CCN(CC4CCCCC4)CC3)nc(N3CCCN(C(C)C)...       UNC 0631
# 872                      CCc1nc(N)nc(N)c1-c1ccc(Cl)cc1  Pyrimethamine
# 873  CCN(CC)CCN(Cc1ccc(-c2ccc(C(F)(F)F)cc2)cc1)C(=O...     Darapladib
# 874  Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)...      Nilotinib
#
# [875 rows x 2 columns]

# %% [markdown]
# #

# %% [markdown]
# # How many drugs in DrugCentral were profiled in DeepCoverageAPI?

# %%
drugcentral_smiles_list = subset_smiles_df['SMILES_String'].unique()
dcmoa_smiles_list = dcmoa_id_df['SMILES_String'].unique()

# %%
subset_smiles_df['DeepCoverageMOA'] = np.where(subset_smiles_df['SMILES_String'].isin(dcmoa_smiles_list), 'Yes', 'No')

# %%
subset_smiles_df['DeepCoverageMOA'].value_counts()
# Out:
# DeepCoverageMOA
# No     3892
# Yes     207
# Name: count, dtype: int64

# %%
subset_smiles_df
# Out:
#                                                  SMILES    ID  \
# 0     CNC(=O)C1=C(C=C(C=C1)C2=NN3C(=CN=C3N=C2)CC4=CC...  5392
# 1     CC(C)(COC1=CN2C(=C(C=N2)C#N)C(=C1)C3=CN=C(C=C3...  5393
# 2     CCN1C2=CC(=NC=C2C=C(C1=O)C3=CC(=C(C=C3Br)F)NC(...  5394
# 3     C[C@]12CC[C@H]3[C@H]([C@@H]1C[C@H]([C@@H]2O)[1...  5395
# 4         C1=CC2=C(C=C1C3=CN=C(C=C3)[18F])NC4=C2C=NC=C4  5396
# ...                                                 ...   ...
# 4094  COC(=O)[C@@H]([C@H]1CCCCN1C(=O)OC[N+]2=CC=CC(=...  5448
# 4095  C[C@]12CC[C@H]3[C@H]([C@@H]1[C@H]([C@H]([C@@H]...  5450
# 4096      OC(=O)CC[C@H](NC(=O)N[C@@H](CCCCNC(=O)C1=C...  5458
# 4097  CCN1CCN(CC1)C2=CC=C(C=C2)NC3=CC(=NC=N3)N(C)C(=...  5459
# 4098  C1CC1CN2CCC34CC(=O)CCC3(C2CC5=C4C(=C(C=C5)C(=O...  5460
#
#                         INN                                       Molecule  \
# 0                capmatinib  <rdkit.Chem.rdchem.Mol object at 0x144a88eb0>
# 1             selpercatinib  <rdkit.Chem.rdchem.Mol object at 0x144a893f0>
# 2                ripretinib  <rdkit.Chem.rdchem.Mol object at 0x144a89380>
# 3      fluoroestradiol F 18  <rdkit.Chem.rdchem.Mol object at 0x144a89310>
# 4         flortaucipir F 18  <rdkit.Chem.rdchem.Mol object at 0x144a892a0>
# ...                     ...                                            ...
# 4094  serdexmethylphenidate  <rdkit.Chem.rdchem.Mol object at 0x144f25000>
# 4095               estetrol  <rdkit.Chem.rdchem.Mol object at 0x144f25070>
# 4096     piflufolastat F-18  <rdkit.Chem.rdchem.Mol object at 0x144f250e0>
# 4097           infigratinib  <rdkit.Chem.rdchem.Mol object at 0x144f25150>
# 4098            samidorphan  <rdkit.Chem.rdchem.Mol object at 0x144f251c0>
#
#                                           SMILES_String DeepCoverageMOA
# 0     CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F              No
# 1     COc1ccc(CN2C3CC2CN(c2ccc(-c4cc(OCC(C)(C)O)cn5n...              No
# 2     CCn1c(=O)c(-c2cc(NC(=O)Nc3ccccc3)c(F)cc2Br)cc2...              No
# 3     C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1C[C@...              No
# 4              [18F]c1ccc(-c2ccc3c(c2)[nH]c2ccncc23)cn1              No
# ...                                                 ...             ...
# 4094  COC(=O)[C@H](c1ccccc1)[C@H]1CCCCN1C(=O)OC[n+]1...              No
# 4095  C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1[C@@...              No
# 4096  O=C(O)CC[C@H](NC(=O)N[C@@H](CCCCNC(=O)c1ccc([1...              No
# 4097  CCN1CCN(c2ccc(Nc3cc(N(C)C(=O)Nc4c(Cl)c(OC)cc(O...              No
# 4098  NC(=O)c1ccc2c(c1O)C13CCN(CC4CC4)C(C2)C1(O)CCC(...              No
#
# [4099 rows x 6 columns]

# %% [markdown]
# #

# %% [markdown]
# # Read DeepCoverageMOA Data

# %%
proteomics_df = pd.read_excel('../data/DeepCoverageMOA/raw_data/41587_2022_1539_MOESM5_ESM.xlsx')

# %%
proteomics_df
# Out:
#                                Row             Column  Pearson (r)     n  \
# 0                    Nutlin3a_MDM2   Idasanutlin_MDM2     0.905866  8492
# 1     Vorinostat_HDAC1;HDAC3;HDAC6  Quisinostat_HDAC1     0.904564  8400
# 2                      AZ 628_RAF1      MEK162_MAP2K1     0.899967  8227
# 3                TCS ERK 11e_MAPK1        AZ 628_RAF1     0.889503  8267
# 4                   ONX 0914_PSMB8       MG-132_PSMB5     0.884305  8258
# ...                            ...                ...          ...   ...
# 2538                 L-779450_RAF1    Taranabant_CNR1     0.407294  8503
# 2539                  CGP77675_SRC    Aztreonam_LACTB    -0.407277  8443
# 2540            Pimavanserin_HTR2A    Saracatinib_SRC     0.407239  8480
# 2541         STK410283_MAP3K9;TNIK    Saracatinib_SRC     0.407234  8327
# 2542                 MEK162_MAP2K1   c-Fms-IN-3_CSF1R    -0.407146  8306
#
#            p-value       q-value
# 0     2.220446e-16  4.080696e-13
# 1     2.220446e-16  4.080696e-13
# 2     2.220446e-16  4.080696e-13
# 3     2.220446e-16  4.080696e-13
# 4     2.220446e-16  4.080696e-13
# ...            ...           ...
# 2538  6.662036e-06  9.908778e-04
# 2539  6.668409e-06  9.916993e-04
# 2540  6.682735e-06  9.935452e-04
# 2541  6.684710e-06  9.937997e-04
# 2542  6.718553e-06  9.981556e-04
#
# [2543 rows x 6 columns]

# %% [markdown]
# #

# %% [markdown]
# ## Create Drug1 and Drug2 Names

# %%
proteomics_df['Drug1'] = proteomics_df['Row'].map(lambda x: x.split('_')[0])

# %%
proteomics_df['Gene1'] = proteomics_df['Row'].map(lambda x: x.split('_')[1])

# %%
proteomics_df['Drug2'] = proteomics_df['Column'].map(lambda x: x.split('_')[0])

# %%
proteomics_df['Gene2'] = proteomics_df['Column'].map(lambda x: x.split('_')[1])

# %% [markdown]
# #

# %% [markdown]
# # Add STRING per Name

# %%
drug1_proteomics_df = pd.merge(proteomics_df, subset_dcmoa_id_df, left_on = 'Drug1', right_on = 'Compound Name', how = 'left')

# %%
drug1_proteomics_df = drug1_proteomics_df.rename(columns = {'SMILES_String': 'Drug1_SMILES'})

# %%
drug1_proteomics_df =  drug1_proteomics_df.drop(columns = ['Compound Name'])

# %%
drug2_proteomics_df = pd.merge(drug1_proteomics_df, subset_dcmoa_id_df, left_on = 'Drug2', right_on = 'Compound Name', how = 'left')

# %%
drug2_proteomics_df = drug2_proteomics_df.rename(columns = {'SMILES_String': 'Drug2_SMILES'})

# %%
drug2_proteomics_df =  drug2_proteomics_df.drop(columns = ['Compound Name'])

# %% [markdown]
# #

# %% [markdown]
# # Map DCMOA IDs to DrugCentral IDs

# %%
drug1_proteomics_name_df = pd.merge(drug2_proteomics_df, structure_drugid_df[['SMILES_String', 'DRUG_NAME', 'STRUCT_ID']], left_on = 'Drug1_SMILES', right_on = 'SMILES_String', how = 'left')

# %%
drug1_proteomics_name_df = drug1_proteomics_name_df.rename(columns = {'DRUG_NAME': 'DRUG_NAME_1', 'STRUCT_ID': 'STRUCT_ID_1'})

# %%
drug1_proteomics_name_df = drug1_proteomics_name_df.drop(columns = ['SMILES_String'])

# %%
drug2_proteomics_name_df = pd.merge(drug1_proteomics_name_df, structure_drugid_df[['SMILES_String', 'DRUG_NAME', 'STRUCT_ID']], left_on = 'Drug2_SMILES', right_on = 'SMILES_String', how = 'left')

# %%
drug2_proteomics_name_df = drug2_proteomics_name_df.rename(columns = {'DRUG_NAME': 'DRUG_NAME_2', 'STRUCT_ID': 'STRUCT_ID_2'})

# %%
drug2_proteomics_name_df = drug2_proteomics_name_df.drop(columns = ['SMILES_String',])

# %% [markdown]
# #

# %% [markdown]
# # Convert DrugCentral Strucutre IDs for LINCS Mapping

# %%
drugcentral_dcmoa_df = drug2_proteomics_name_df[(drug2_proteomics_name_df['DRUG_NAME_1'].isna() == False) & (drug2_proteomics_name_df['DRUG_NAME_2'].isna() == False)]

# %%
drugcentral_dcmoa_df['STRUCT_ID_1'] = drugcentral_dcmoa_df['STRUCT_ID_1'].map(lambda x: int(x))
# Out:
# /var/folders/4c/kr7lv7195d92x2l4kyj4r3z00000gn/T/ipykernel_89620/4122659653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drugcentral_dcmoa_df['STRUCT_ID_1'] = drugcentral_dcmoa_df['STRUCT_ID_1'].map(lambda x: int(x))

# %%
drugcentral_dcmoa_df['STRUCT_ID_2'] = drugcentral_dcmoa_df['STRUCT_ID_2'].map(lambda x: int(x))
# Out:
# /var/folders/4c/kr7lv7195d92x2l4kyj4r3z00000gn/T/ipykernel_89620/2782093337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drugcentral_dcmoa_df['STRUCT_ID_2'] = drugcentral_dcmoa_df['STRUCT_ID_2'].map(lambda x: int(x))

# %%
drugcentral_dcmoa_df = drugcentral_dcmoa_df.drop(columns = ['Row', 'Column'])

# %% [markdown]
# #

# %% [markdown]
# # Write DeepCoverageMOA to LINCS Mapping File

# %%
subset_drugcentral_dcmoa_df = drugcentral_dcmoa_df[[
 'DRUG_NAME_1',
 'STRUCT_ID_1',
 'DRUG_NAME_2',
 'STRUCT_ID_2',
'Drug1_SMILES',
 'Drug2_SMILES',
'Pearson (r)',
 'n',
 'p-value',
 'q-value'
]]

# %%
subset_drugcentral_dcmoa_df = subset_drugcentral_dcmoa_df.rename(columns = {'Pearson (r)': 'DCMOA Pearson (r)',
                                                                             'n': 'DCMOA n',
                                                                             'p-value': 'DCMOA  p-value',
                                                                             'q-value': 'DCMOA q-value'
                                                                           })

# %%
subset_drugcentral_dcmoa_df
# Out:
#       DRUG_NAME_1  STRUCT_ID_1    DRUG_NAME_2  STRUCT_ID_2  \
# 19    palbociclib         4941     ribociclib         5218
# 33      sunitinib         2544      bosutinib         4359
# 63     formestane         1238  betamethasone          348
# 113   encorafenib         5289    binimetinib         5290
# 192     sunitinib         2544    encorafenib         5289
# ...           ...          ...            ...          ...
# 2353   fingolimod         4167    simvastatin         2445
# 2424   fingolimod         4167     fedratinib         5347
# 2440    dasatinib          785      pazopanib         4118
# 2474    bosutinib         4359  betamethasone          348
# 2487    sunitinib         2544      aztreonam          279
#
#                                            Drug1_SMILES  \
# 19    CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2C...
# 33    CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F...
# 63    C[C@]12CCC(=O)C(O)=C1CC[C@@H]1[C@@H]2CC[C@]2(C...
# 113   COC(=O)N[C@@H](C)CNc1nccc(-c2cn(C(C)C)nc2-c2cc...
# 192   CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F...
# ...                                                 ...
# 2353                     CCCCCCCCc1ccc(CCC(N)(CO)CO)cc1
# 2424                     CCCCCCCCc1ccc(CCC(N)(CO)CO)cc1
# 2440  Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(C...
# 2474  COc1cc(Nc2c(C#N)cnc3cc(OCCCN4CCN(C)CC4)c(OC)cc...
# 2487  CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F...
#
#                                            Drug2_SMILES  DCMOA Pearson (r)  \
# 19    CN(C)C(=O)c1cc2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n1C1...           0.815885
# 33    COc1cc(Nc2c(C#N)cnc3cc(OCCCN4CCN(C)CC4)c(OC)cc...           0.776625
# 63    C[C@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@...           0.741963
# 113       Cn1cnc2c(F)c(Nc3ccc(Br)cc3F)c(C(=O)NOCCO)cc21           0.708916
# 192   COC(=O)N[C@@H](C)CNc1nccc(-c2cn(C(C)C)nc2-c2cc...           0.676738
# ...                                                 ...                ...
# 2353  CCC(C)(C)C(=O)O[C@H]1C[C@@H](C)C=C2C=C[C@H](C)...           0.416534
# 2424  Cc1cnc(Nc2ccc(OCCN3CCCC3)cc2)nc1Nc1cccc(S(=O)(...           0.412612
# 2440  Cc1ccc(Nc2nccc(N(C)c3ccc4c(C)n(C)nc4c3)n2)cc1S...           0.411989
# 2474  C[C@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@...          -0.410643
# 2487  C[C@H]1[C@H](NC(=O)/C(=N\OC(C)(C)C(=O)O)c2csc(...          -0.410105
#
#       DCMOA n  DCMOA  p-value  DCMOA q-value
# 19       8577    2.220446e-16   4.080696e-13
# 33       7746    2.220446e-16   4.080696e-13
# 63       8869    2.220446e-16   4.080696e-13
# 113      7985    2.220446e-16   4.080696e-13
# 192      7582    2.220446e-16   4.080696e-13
# ...       ...             ...            ...
# 2353     8110    3.899823e-06   6.271537e-04
# 2424     8085    4.904502e-06   7.641203e-04
# 2440     8545    5.085039e-06   7.878903e-04
# 2474     8277    5.496717e-06   8.411267e-04
# 2487     7835    5.670162e-06   8.631631e-04
#
# [91 rows x 10 columns]

# %%
subset_drugcentral_dcmoa_df.to_csv('../data/DeepCoverageMOA/analyzed_data/deepcoveragemoa.lincs.csv', index = False)
