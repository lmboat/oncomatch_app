# %%
import pandas as pd
import numpy as np
import os, sys, math

# %% [markdown]
# #

# %% [markdown]
# # Read Drug Target Data

# %% [markdown]
# ## https://drugcentral.org/download

# %%
drugcentral_df = pd.read_csv('../data/drug.target.interaction.tsv', sep = '\t')
drugcentral_df.head()
# Out:
#          DRUG_NAME  STRUCT_ID  \
# 0  levobupivacaine          4
# 1  levobupivacaine          4
# 2  levobupivacaine          4
# 3  levobupivacaine          4
# 4  levobupivacaine          4
#
#                                          TARGET_NAME TARGET_CLASS ACCESSION  \
# 0  Potassium voltage-gated channel subfamily H me...  Ion channel    Q12809
# 1        Sodium channel protein type 1 subunit alpha  Ion channel    P35498
# 2        Sodium channel protein type 4 subunit alpha  Ion channel    P35499
# 3              Prostaglandin E2 receptor EP1 subtype         GPCR    P34995
# 4                                Cytochrome P450 2D6       Enzyme    P10635
#
#      GENE    SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  \
# 0   KCNH2  KCNH2_HUMAN      4.890       NaN     IC50
# 1   SCN1A  SCN1A_HUMAN      5.790       NaN     IC50
# 2   SCN4A  SCN4A_HUMAN        NaN       NaN      NaN
# 3  PTGER1  PE2R1_HUMAN        NaN       NaN      NaN
# 4  CYP2D6  CP2D6_HUMAN      6.707       NaN     IC50
#
#                                          ACT_COMMENT   ACT_SOURCE RELATION  \
# 0  Inhibition of wild-type human ERG channel expr...       CHEMBL        =
# 1                                                NaN    WOMBAT-PK        =
# 2                                                NaN    WOMBAT-PK      NaN
# 3                                                NaN    WOMBAT-PK      NaN
# 4  DRUGMATRIX: CYP450, 2D6 enzyme inhibition (sub...  DRUG MATRIX        =
#
#    MOA MOA_SOURCE ACT_SOURCE_URL  \
# 0  NaN        NaN            NaN
# 1  NaN        NaN            NaN
# 2  1.0     CHEMBL            NaN
# 3  NaN        NaN            NaN
# 4  NaN        NaN            NaN
#
#                                       MOA_SOURCE_URL ACTION_TYPE    TDL  \
# 0                                                NaN         NaN  Tclin
# 1                                                NaN         NaN  Tclin
# 2  https://www.ebi.ac.uk/chembl/compound/inspect/...     BLOCKER  Tclin
# 3                                                NaN         NaN  Tclin
# 4                                                NaN         NaN  Tclin
#
#        ORGANISM
# 0  Homo sapiens
# 1  Homo sapiens
# 2  Homo sapiens
# 3  Homo sapiens
# 4  Homo sapiens

# %% [markdown]
# #

# %% [markdown]
# # Read FDA Approved

# %%
fda_df = pd.read_csv('../data/FDA_Approved.csv', header = None)
fda_df.columns = ['DRUG_NUMBER', 'DRUG_NAME']
fda_df.head()
# Out:
#    DRUG_NUMBER    DRUG_NAME
# 0         2104   perflutren
# 1         1834  monobenzone
# 2         2684   tobramycin
# 3         3051     butamben
# 4         3103   citrulline

# %% [markdown]
# #

# %% [markdown]
# # Read EMA Approved

# %%
ema_df = pd.read_csv('../data/EMA_Approved.csv', header = None)
ema_df.columns = ['DRUG_NUMBER', 'DRUG_NAME']
ema_df.head()
# Out:
#    DRUG_NUMBER             DRUG_NAME
# 0         5405  belantamab mafodotin
# 1         5376            remdesivir
# 2         5415             lumasiran
# 3         5416         setmelanotide
# 4         5417           bulevirtide

# %% [markdown]
# #

# %% [markdown]
# # Read PMDA Approved

# %%
pmda_df = pd.read_csv('../data/PMDA_Approved.csv', header = None)
pmda_df.columns = ['DRUG_NUMBER', 'DRUG_NAME']
pmda_df.head()
# Out:
#    DRUG_NUMBER    DRUG_NAME
# 0         5392   capmatinib
# 1         5400  remimazolam
# 2         5408  viltolarsen
# 3         5419   filgotinib
# 4         5420   vadadustat

# %% [markdown]
# #

# %% [markdown]
# # Read Cancer Data

# %% [markdown]
# ## https://cancer.sanger.ac.uk/census

# %%
gene_df = pd.read_csv('../data/Cosmic_CancerGeneCensus_v99_GRCh38.tsv', sep = '\t')
gene_df.head()
# Out:
#   GENE_SYMBOL                                               NAME  \
# 0        A1CF                     APOBEC1 complementation factor
# 1        ABI1                                   abl interactor 1
# 2        ABL1  ABL proto-oncogene 1, non-receptor tyrosine ki...
# 3        ABL2  ABL proto-oncogene 2, non-receptor tyrosine ki...
# 4       ACKR3                      atypical chemokine receptor 3
#
#   COSMIC_GENE_ID CHROMOSOME  GENOME_START  GENOME_STOP  CHR_BAND SOMATIC  \
# 0      COSG68236         10    50799409.0   50885675.0  10q11.23       y
# 1     COSG100962         10    26746593.0   26861087.0   10p12.1       y
# 2     COSG106650          9   130713946.0  130887675.0   9q34.12       y
# 3      COSG93778          1   179099327.0  179229684.0    1q25.2       y
# 4      COSG97311          2   236567787.0  236582358.0    2q37.3       y
#
#   GERMLINE TUMOUR_TYPES_SOMATIC  ... CANCER_SYNDROME TISSUE_TYPE  \
# 0        n             melanoma  ...             NaN           E
# 1        n                  AML  ...             NaN           L
# 2        n      CML, ALL, T-ALL  ...             NaN           L
# 3        n                  AML  ...             NaN           L
# 4        n               lipoma  ...             NaN           M
#
#   MOLECULAR_GENETICS    ROLE_IN_CANCER MUTATION_TYPES TRANSLOCATION_PARTNER  \
# 0                NaN          oncogene            Mis                   NaN
# 1                Dom       TSG, fusion              T                 KMT2A
# 2                Dom  oncogene, fusion         T, Mis     BCR, ETV6, NUP214
# 3                Dom  oncogene, fusion              T                  ETV6
# 4                Dom  oncogene, fusion              T                 HMGA2
#
#   OTHER_GERMLINE_MUT OTHER_SYNDROME TIER  \
# 0                  n            NaN    2
# 1                  n            NaN    1
# 2                  n            NaN    1
# 3                  n            NaN    1
# 4                  n            NaN    1
#
#                                             SYNONYMS
# 0  A1CF,ENSG00000148584.14,29974,ACF,ACF64,ACF65,...
# 1    ABI1,ENSG00000136754.17,Q8IZP0,10006,ABI-1,E3B1
# 2  ABL1,ENSG00000097007.17,P00519,25,JTK7,c-ABL,p150
# 3              ABL2,ENSG00000143322.19,P42684,27,ARG
# 4   ACKR3,ENSG00000144476.5,P25106,57007,GPR159,RDC1
#
# [5 rows x 21 columns]

# %% [markdown]
# #

# %% [markdown]
# # Append Approval Status to Drug Interaction Data

# %%
fda_ids = list(fda_df['DRUG_NAME'].unique())
ema_ids = list(ema_df['DRUG_NAME'].unique())
pmda_ids = list(pmda_df['DRUG_NAME'].unique())

# %%
len(fda_ids), len(ema_ids), len(pmda_ids)
# Out:
# (2331, 456, 435)

# %%
drugcentral_df['FDA_Approved'] = np.where(drugcentral_df['DRUG_NAME'].isin(fda_ids), 'Yes', 'No')
drugcentral_df['FDA_Approved'].value_counts()
# Out:
# FDA_Approved
# Yes    15315
# No      4063
# Name: count, dtype: int64

# %%
drugcentral_df['EMA_Approved'] = np.where(drugcentral_df['DRUG_NAME'].isin(ema_ids), 'Yes', 'No')
drugcentral_df['EMA_Approved'].value_counts()
# Out:
# EMA_Approved
# No     16228
# Yes     3150
# Name: count, dtype: int64

# %%
drugcentral_df['PMDA_Approved'] = np.where(drugcentral_df['DRUG_NAME'].isin(pmda_ids), 'Yes', 'No')
drugcentral_df['PMDA_Approved'].value_counts()
# Out:
# PMDA_Approved
# No     17035
# Yes     2343
# Name: count, dtype: int64

# %%
drugcentral_df.head()
# Out:
#          DRUG_NAME  STRUCT_ID  \
# 0  levobupivacaine          4
# 1  levobupivacaine          4
# 2  levobupivacaine          4
# 3  levobupivacaine          4
# 4  levobupivacaine          4
#
#                                          TARGET_NAME TARGET_CLASS ACCESSION  \
# 0  Potassium voltage-gated channel subfamily H me...  Ion channel    Q12809
# 1        Sodium channel protein type 1 subunit alpha  Ion channel    P35498
# 2        Sodium channel protein type 4 subunit alpha  Ion channel    P35499
# 3              Prostaglandin E2 receptor EP1 subtype         GPCR    P34995
# 4                                Cytochrome P450 2D6       Enzyme    P10635
#
#      GENE    SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  ...  MOA MOA_SOURCE  \
# 0   KCNH2  KCNH2_HUMAN      4.890       NaN     IC50  ...  NaN        NaN
# 1   SCN1A  SCN1A_HUMAN      5.790       NaN     IC50  ...  NaN        NaN
# 2   SCN4A  SCN4A_HUMAN        NaN       NaN      NaN  ...  1.0     CHEMBL
# 3  PTGER1  PE2R1_HUMAN        NaN       NaN      NaN  ...  NaN        NaN
# 4  CYP2D6  CP2D6_HUMAN      6.707       NaN     IC50  ...  NaN        NaN
#
#   ACT_SOURCE_URL                                     MOA_SOURCE_URL  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN  https://www.ebi.ac.uk/chembl/compound/inspect/...
# 3            NaN                                                NaN
# 4            NaN                                                NaN
#
#   ACTION_TYPE    TDL      ORGANISM FDA_Approved EMA_Approved PMDA_Approved
# 0         NaN  Tclin  Homo sapiens          Yes           No            No
# 1         NaN  Tclin  Homo sapiens          Yes           No            No
# 2     BLOCKER  Tclin  Homo sapiens          Yes           No            No
# 3         NaN  Tclin  Homo sapiens          Yes           No            No
# 4         NaN  Tclin  Homo sapiens          Yes           No            No
#
# [5 rows x 23 columns]

# %% [markdown]
# #

# %% [markdown]
# # Parse Annotations for Cancer Types

# %%
def find_keyword(df, keys):

    key_labels = []

    type_somatic = df['TUMOUR_TYPES_SOMATIC']

    for i in range(len(type_somatic)):
        
        value = type_somatic[i]
        
        if pd.notna(value):
            if ',' in value:
                vals = type_somatic[i].split(',')
            else:
                vals = [value]

            key_found = False
                
            for j in range(len(keys)):
                if keys[j] in vals:
                    key_found = True

            key_labels.append(key_found)
            
        else:
            key_labels.append(False)

    return key_labels

# %%
colon_labels = find_keyword(gene_df, ['colon', 'colorectal', 'colorectal cancer', 'colon cancer', 'colon carcinoma'])
gene_df['Colon'] = colon_labels

# %%
nsclc_labels = find_keyword(gene_df, ['NSCLC'])
gene_df['NSCLC'] = nsclc_labels

# %%
bladder_labels = find_keyword(gene_df, ['bladder', 'bladder carcinoma'])
gene_df['Bladder'] = bladder_labels

# %%
ovarian_labels = find_keyword(gene_df, ['ovarian', 'ovarian cancer', 'clear cell ovarian carcinoma'])
gene_df['Ovarian'] = ovarian_labels

# %%
bladder_df = gene_df[gene_df['Bladder'] == True]
ovarian_df = gene_df[gene_df['Ovarian'] == True]
nsclc_df = gene_df[gene_df['NSCLC'] == True]
colon_df = gene_df[gene_df['Colon'] == True]

# %%
bladder_ids = list(bladder_df['GENE_SYMBOL'].unique())
colon_ids = list(colon_df['GENE_SYMBOL'].unique())
nsclc_ids = list(nsclc_df['GENE_SYMBOL'].unique())
ovarian_ids = list(ovarian_df['GENE_SYMBOL'].unique())

# %%
len(bladder_ids), len(colon_ids), len(nsclc_ids), len(ovarian_ids)
# Out:
# (2, 29, 17, 6)

# %%
drugcentral_df['Bladder'] = np.where(drugcentral_df['GENE'].isin(bladder_ids), 'Yes', 'No')
drugcentral_df['Colon'] = np.where(drugcentral_df['GENE'].isin(colon_ids), 'Yes', 'No')
drugcentral_df['NSCLC'] = np.where(drugcentral_df['GENE'].isin(nsclc_ids), 'Yes', 'No')
drugcentral_df['Ovarian'] = np.where(drugcentral_df['GENE'].isin(ovarian_ids), 'Yes', 'No')

# %%
drugcentral_df['Bladder'].value_counts()
# Out:
# Bladder
# No     19362
# Yes       16
# Name: count, dtype: int64

# %%
drugcentral_df['Colon'].value_counts()
# Out:
# Colon
# No     19308
# Yes       70
# Name: count, dtype: int64

# %%
drugcentral_df['NSCLC'].value_counts()
# Out:
# NSCLC
# No     19312
# Yes       66
# Name: count, dtype: int64

# %%
drugcentral_df['Ovarian'].value_counts()
# Out:
# Ovarian
# No     19374
# Yes        4
# Name: count, dtype: int64

# %%
drugcentral_df.head()
# Out:
#          DRUG_NAME  STRUCT_ID  \
# 0  levobupivacaine          4
# 1  levobupivacaine          4
# 2  levobupivacaine          4
# 3  levobupivacaine          4
# 4  levobupivacaine          4
#
#                                          TARGET_NAME TARGET_CLASS ACCESSION  \
# 0  Potassium voltage-gated channel subfamily H me...  Ion channel    Q12809
# 1        Sodium channel protein type 1 subunit alpha  Ion channel    P35498
# 2        Sodium channel protein type 4 subunit alpha  Ion channel    P35499
# 3              Prostaglandin E2 receptor EP1 subtype         GPCR    P34995
# 4                                Cytochrome P450 2D6       Enzyme    P10635
#
#      GENE    SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  ... ACTION_TYPE    TDL  \
# 0   KCNH2  KCNH2_HUMAN      4.890       NaN     IC50  ...         NaN  Tclin
# 1   SCN1A  SCN1A_HUMAN      5.790       NaN     IC50  ...         NaN  Tclin
# 2   SCN4A  SCN4A_HUMAN        NaN       NaN      NaN  ...     BLOCKER  Tclin
# 3  PTGER1  PE2R1_HUMAN        NaN       NaN      NaN  ...         NaN  Tclin
# 4  CYP2D6  CP2D6_HUMAN      6.707       NaN     IC50  ...         NaN  Tclin
#
#        ORGANISM  FDA_Approved EMA_Approved PMDA_Approved Bladder Colon NSCLC  \
# 0  Homo sapiens           Yes           No            No      No    No    No
# 1  Homo sapiens           Yes           No            No      No    No    No
# 2  Homo sapiens           Yes           No            No      No    No    No
# 3  Homo sapiens           Yes           No            No      No    No    No
# 4  Homo sapiens           Yes           No            No      No    No    No
#
#   Ovarian
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
#
# [5 rows x 27 columns]

# %% [markdown]
# #

# %% [markdown]
# # Write Output File for Connecting Drug-Gene-Cancer Type Interactions

# %%
drugcentral_df.to_csv('../data/drug.target.interaction.fda.cosmic.cancer.type.tsv', sep = '\t', index = False)
